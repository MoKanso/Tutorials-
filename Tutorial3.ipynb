# %%
#EXERCISE ONE ______________________

import statsmodels.api as sm
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('/Users/kanso/OneDrive/Desktop/Kanso/University/Year 3/Principles of Data Science/Tutorial 3/accord_sedan.csv')

df
# Out:
#      price  mileage  year trim engine transmission
# 0    14995    67697  2006   ex  4 Cyl       Manual
# 1    11988    73738  2006   ex  4 Cyl       Manual
# 2    11999    80313  2006   lx  4 Cyl    Automatic
# 3    12995    86096  2006   lx  4 Cyl    Automatic
# 4    11333    79607  2006   lx  4 Cyl    Automatic
# ..     ...      ...   ...  ...    ...          ...
# 412  12456    67564  2006   lx  4 Cyl    Automatic
# 413  10995    69775  2006   ex  4 Cyl    Automatic
# 414  16000    77997  2006  exl  4 Cyl    Automatic
# 415  14700    61892  2006   ex  4 Cyl    Automatic
# 416  14755    43034  2006   ex  4 Cyl    Automatic
#
# [417 rows x 6 columns]

# %%
boxplot = df.boxplot(column=['price', 'mileage'])

# %%
df.plot.scatter(x='price', y='mileage').set_title('Relationship between price and mileage')
# Out:
# Text(0.5, 1.0, 'Relationship between price and mileage')

# %%
standard_deviation= df.std()
print("The standard deviation is:   \n")
print(standard_deviation)
# Out:
# The standard deviation is:
#
# price       2061.430034
# mileage    25957.872271
# year           0.000000
# dtype: float64

# %%
print("The mean of price is:   \n")
df["price"].mean()
# Out:
# The mean of price is:
# 12084.242206235012

# %%
df['isOutlierPrice'] = float
df['isOutlierMileage'] = float

# %%
df
# Out:
#      price  mileage  year trim engine transmission   isOutlierPrice  \
# 0    14995    67697  2006   ex  4 Cyl       Manual  <class 'float'>
# 1    11988    73738  2006   ex  4 Cyl       Manual  <class 'float'>
# 2    11999    80313  2006   lx  4 Cyl    Automatic  <class 'float'>
# 3    12995    86096  2006   lx  4 Cyl    Automatic  <class 'float'>
# 4    11333    79607  2006   lx  4 Cyl    Automatic  <class 'float'>
# ..     ...      ...   ...  ...    ...          ...              ...
# 412  12456    67564  2006   lx  4 Cyl    Automatic  <class 'float'>
# 413  10995    69775  2006   ex  4 Cyl    Automatic  <class 'float'>
# 414  16000    77997  2006  exl  4 Cyl    Automatic  <class 'float'>
# 415  14700    61892  2006   ex  4 Cyl    Automatic  <class 'float'>
# 416  14755    43034  2006   ex  4 Cyl    Automatic  <class 'float'>
#
#     isOutlierMileage
# 0    <class 'float'>
# 1    <class 'float'>
# 2    <class 'float'>
# 3    <class 'float'>
# 4    <class 'float'>
# ...

# %%
print("The mean of the price is",df['price'].mean())
# Out:
# The mean of the price is 12084.242206235012

# %%
print("The standard deviation of the price is",df['price'].std())
# Out:
# The standard deviation of the price is 2061.430033967955

# %%
#Question 5 ... ... ...

# %%
#________________---EXERCISE 2---_____________________

# %%
df2 = pd.read_csv('/Users/kanso/OneDrive/Desktop/Kanso/University/Year 3/Principles of Data Science/Tutorial 3/TB_burden_countries_2014-09-29.csv')

df2
# Out:
#           country iso2 iso3  iso_numeric g_whoregion  year  e_pop_num  \
# 0     Afghanistan   AF  AFG            4         EMR  1990   11731193
# 1     Afghanistan   AF  AFG            4         EMR  1991   12612043
# 2     Afghanistan   AF  AFG            4         EMR  1992   13811876
# 3     Afghanistan   AF  AFG            4         EMR  1993   15175325
# 4     Afghanistan   AF  AFG            4         EMR  1994   16485018
# ...           ...  ...  ...          ...         ...   ...        ...
# 4898     Zimbabwe   ZW  ZWE          716         AFR  2008   12784041
# 4899     Zimbabwe   ZW  ZWE          716         AFR  2009   12888918
# 4900     Zimbabwe   ZW  ZWE          716         AFR  2010   13076978
# 4901     Zimbabwe   ZW  ZWE          716         AFR  2011   13358738
# 4902     Zimbabwe   ZW  ZWE          716         AFR  2012   13724317
#
#       e_prev_100k  e_prev_100k_lo  e_prev_100k_hi  ...  e_inc_tbhiv_100k  \
# ...

# %%
c_cdr_hi_mean = df2['c_cdr_hi'].fillna(df2['c_cdr_hi'].mean())
c_cdr_hi_mean
# Out:
# 0        32.00000
# 1       120.00000
# 2        83.01595
# 3        83.01595
# 4        83.01595
#           ...
# 4898     51.00000
# 4899     65.00000
# 4900     69.00000
# 4901     62.00000
# 4902     60.00000
# Name: c_cdr_hi, Length: 4903, dtype: float64

# %%
c_cdr_lo_mean = df2['c_cdr_lo'].fillna(df2['c_cdr_lo'].mean())
c_cdr_lo_mean
# Out:
# 0       13.000000
# 1       77.000000
# 2       57.608038
# 3       57.608038
# 4       57.608038
#           ...
# 4898    32.000000
# 4899    40.000000
# 4900    43.000000
# 4901    38.000000
# 4902    37.000000
# Name: c_cdr_lo, Length: 4903, dtype: float64

# %%
c_cdr_mean = df2['c_cdr'].fillna(df2['c_cdr'].mean())
c_cdr_mean
# Out:
# 0       20.000000
# 1       97.000000
# 2       67.570706
# 3       67.570706
# 4       67.570706
#           ...
# 4898    40.000000
# 4899    50.000000
# 4900    53.000000
# 4901    48.000000
# 4902    46.000000
# Name: c_cdr, Length: 4903, dtype: float64

# %%
# Display summary statistics
stats=df2.describe()
print(stats)
# Out:
#        iso_numeric         year     e_pop_num  e_prev_100k  e_prev_100k_lo  \
# count  4903.000000  4903.000000  4.903000e+03  4892.000000     4892.000000
# mean    433.487457  2001.042219  2.899179e+07   207.694422       93.683299
# std     255.202944     6.643548  1.177827e+08   269.720954      138.015090
# min       4.000000  1990.000000  1.129000e+03     0.260000        0.080000
# 25%     212.000000  1995.000000  5.508830e+05    25.000000       10.000000
# 50%     430.000000  2001.000000  5.140332e+06    93.000000       37.000000
# 75%     646.000000  2007.000000  1.732282e+07   306.000000      129.250000
# max     894.000000  2012.000000  1.377065e+09  1860.000000     1316.000000
#
#        e_prev_100k_hi    e_prev_num  e_prev_num_lo  e_prev_num_hi  \
# count     4892.000000  4.892000e+03   4.892000e+03   4.892000e+03
# mean       378.137001  6.914368e+04   4.366106e+04   1.064607e+05
# std        501.059424  3.304527e+05   2.729764e+05   4.152786e+05
# ...
