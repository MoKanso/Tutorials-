# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('/Users/kanso/OneDrive/Desktop/Kanso/University/Year 3/Principles of Data Science/Tutorial 4/censusCrimeClean.csv')

df
# Out:
#             communityname  fold  population  householdsize  racepctblack  \
# 0            Lakewoodcity     1        0.19           0.33          0.02
# 1             Tukwilacity     1        0.00           0.16          0.12
# 2            Aberdeentown     1        0.00           0.42          0.49
# 3     Willingborotownship     1        0.04           0.77          1.00
# 4       Bethlehemtownship     1        0.01           0.55          0.02
# ...                   ...   ...         ...            ...           ...
# 1989    TempleTerracecity    10        0.01           0.40          0.10
# 1990          Seasidecity    10        0.05           0.96          0.46
# 1991        Waterburytown    10        0.16           0.37          0.25
# 1992          Walthamcity    10        0.08           0.51          0.06
# 1993          Ontariocity    10        0.20           0.78          0.14
#
#       racePctWhite  racePctAsian  racePctHisp  agePct12t21  agePct12t29  ...  \
# ...

# %%
#data = pd.DataFrame(np.zeros(shape=(5,2)),columns=["medIncome","ViolentCrimesPerPop"])

#def mapper(x):
#    return ('first', 'second')

#data['t1'], data['t2'] = data['ViolentCrimesPerPop'].map(mapper).apply(pd.Series).values.T

#print(data)

# %%
#select columns called 'medIncome' and 'ViolentCrimesPerPop'
df_new = df[['medIncome', 'ViolentCrimesPerPop']]

#view new DataFrame made
df_new
# Out:
#       medIncome  ViolentCrimesPerPop
# 0          0.37                 0.20
# 1          0.31                 0.67
# 2          0.30                 0.43
# 3          0.58                 0.12
# 4          0.50                 0.03
# ...         ...                  ...
# 1989       0.42                 0.09
# 1990       0.28                 0.45
# 1991       0.31                 0.23
# 1992       0.44                 0.19
# 1993       0.40                 0.48
#
# [1994 rows x 2 columns]

# %%
# Display summary statistics
stats=df_new.describe()
print(stats)
# Out:
#          medIncome  ViolentCrimesPerPop
# count  1994.000000          1994.000000
# mean      0.361123             0.237979
# std       0.209362             0.232985
# min       0.000000             0.000000
# 25%       0.200000             0.070000
# 50%       0.320000             0.150000
# 75%       0.490000             0.330000
# max       1.000000             1.000000

# %%
df2 = df_new[['medIncome','ViolentCrimesPerPop']].dropna()
df.corr() # returns a matrix with each columns correlation to all others
# Out:
#                          fold  population  householdsize  racepctblack  \
# fold                 1.000000   -0.007552       0.035488      0.003524
# population          -0.007552    1.000000      -0.046148      0.231178
# householdsize        0.035488   -0.046148       1.000000     -0.067109
# racepctblack         0.003524    0.231178      -0.067109      1.000000
# racePctWhite        -0.004436   -0.300845      -0.235907     -0.794389
# ...                       ...         ...            ...           ...
# PctSameState85      -0.027938   -0.089638      -0.003277     -0.002894
# LandArea             0.017846    0.713652      -0.015078      0.149758
# PopDens             -0.012570    0.231897      -0.004072      0.095053
# PctUsePubTrans      -0.000541    0.270356      -0.051506      0.147023
# ViolentCrimesPerPop -0.032577    0.367157      -0.034923      0.631264
#
#                      racePctWhite  racePctAsian  racePctHisp  agePct12t21  \
# ...

# %%
# PCC using Numpy
import numpy as np
arrayOne = np.array(df['medIncome'])
arrayTwo = np.array(df['ViolentCrimesPerPop'])
np.corrcoef(arrayOne, arrayTwo)
# Out:
# array([[ 1.        , -0.42422062],
#        [-0.42422062,  1.        ]])

# %%
import scipy
x = arrayOne
y = arrayTwo
# x and y are numpy array with shape (N,)
coeff = scipy.stats.spearmanr(x, y)
print(coeff)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-cab231c483d6> in <module>
#       3 y = arrayTwo
#       4 # x and y are numpy array with shape (N,)
# ----> 5 coeff = scipy.stats.spearmanr(x, y)
#       6 print(coeff)
#
# AttributeError: module 'scipy' has no attribute 'stats'

# %%
import seaborn as sns
sns.scatterplot(x="medIncome", y="ViolentCrimesPerPop", data=df2, color='purple')
sns.lmplot(x="medIncome", y="ViolentCrimesPerPop", data=df2)

# %%
from scipy import stats
stats.pearsonr(df2['medIncome'], df2['ViolentCrimesPerPop'])
# Out:
# (-0.424220616726126, 6.334424808048533e-88)

# %%
cormat = df2.corr()
round(cormat,2)
# Out:
#                      medIncome  ViolentCrimesPerPop
# medIncome                 1.00                -0.42
# ViolentCrimesPerPop      -0.42                 1.00

# %%
sns.heatmap(cormat);

# %%
from scipy import stats
stats.spearmanr(df2['medIncome'], df2['ViolentCrimesPerPop'])
# Out:
# SpearmanrResult(correlation=-0.482169950997556, pvalue=1.2978853095169542e-116)

# %%
r = df2.corr(method="spearman")
plt.figure(figsize=(10,6))
heatmap = sns.heatmap(df2.corr(), vmin=-1, 
                      vmax=1, annot=True)
plt.title("Spearman Correlation")


plt.show()

# %%
df3 = pd.read_csv('/Users/kanso/OneDrive/Desktop/Kanso/University/Year 3/Principles of Data Science/Tutorial 4/Heart.csv')

df3
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df3.insert(0, 'gender', value = 0 )

# %%
df3
# Out:
#      gender  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0         0   63    1   3       145   233    1        0      150      0
# 1         0   37    1   2       130   250    0        1      187      0
# 2         0   41    0   1       130   204    0        0      172      0
# 3         0   56    1   1       120   236    0        1      178      0
# 4         0   57    0   0       120   354    0        1      163      1
# ..      ...  ...  ...  ..       ...   ...  ...      ...      ...    ...
# 298       0   57    0   0       140   241    0        1      123      1
# 299       0   45    1   3       110   264    0        1      132      0
# 300       0   68    1   0       144   193    1        1      141      0
# 301       0   57    1   0       130   131    0        1      115      1
# 302       0   57    0   1       130   236    0        0      174      0
#
#      oldpeak  slope  ca  thal  target
# 0        2.3      0   0     1       1
# ...

# %%
print("Standard deviation \n")
df3_std = np.std(df3)
print(np.std(df3))
# Out:
# Standard deviation
#
# gender       0.000000
# age          9.067102
# sex          0.465241
# cp           1.030348
# trestbps    17.509178
# chol        51.745151
# fbs          0.355610
# restecg      0.524991
# thalach     22.867333
# exang        0.469019
# oldpeak      1.159157
# slope        0.615208
# ca           1.020918
# thal         0.611265
# target       0.498011
# dtype: float64

# %%
ax = df3_std.plot.hist(bins=12, alpha=0.5)

# %%
print("Mean \n")
df_mean = np.mean(df3)
print(np.mean(df3))
# Out:
# Mean
#
# gender        0.000000
# age          54.366337
# sex           0.683168
# cp            0.966997
# trestbps    131.623762
# chol        246.264026
# fbs           0.148515
# restecg       0.528053
# thalach     149.646865
# exang         0.326733
# oldpeak       1.039604
# slope         1.399340
# ca            0.729373
# thal          2.313531
# target        0.544554
# dtype: float64

# %%
ax = df_mean.plot.hist(bins=12, alpha=0.5)

# %%
stats_1=df3.describe()
print(stats_1)
# Out:
#        gender         age         sex          cp    trestbps        chol  \
# count   303.0  303.000000  303.000000  303.000000  303.000000  303.000000
# mean      0.0   54.366337    0.683168    0.966997  131.623762  246.264026
# std       0.0    9.082101    0.466011    1.032052   17.538143   51.830751
# min       0.0   29.000000    0.000000    0.000000   94.000000  126.000000
# 25%       0.0   47.500000    0.000000    0.000000  120.000000  211.000000
# 50%       0.0   55.000000    1.000000    1.000000  130.000000  240.000000
# 75%       0.0   61.000000    1.000000    2.000000  140.000000  274.500000
# max       0.0   77.000000    1.000000    3.000000  200.000000  564.000000
#
#               fbs     restecg     thalach       exang     oldpeak       slope  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.148515    0.528053  149.646865    0.326733    1.039604    1.399340
# ...

# %%
#Count the number with the disease for each gender type
hasDiseaseCount=df3[df3.hasDisease==True].groupby("gender").count().hasDisease

#Count the number of gender type
totalCount=df3.groupby("gender").count()['hasDisease']

#combine into a dataframe (both are indexed with gender, so will be matched) and specify the columns
p=pd.concat([hasDiseaseCount, totalCount], axis=1)
p.columns = ["heartDiseaseCount", "totalCount"]

#create a new column and calculate the proportion
p['propHeartDisease']=p["heartDiseaseCount"]/p["totalCount"]

#print the results
print(p.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-9db2be027bf7> in <module>
#       1 #Count the number with the disease for each gender type
# ----> 2 hasDiseaseCount=df3[df3.hasDisease==True].groupby("gender").count().hasDisease
#       3
#       4 #Count the number of gender type
#       5 totalCount=df3.groupby("gender").count()['hasDisease']
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'hasDisease'
