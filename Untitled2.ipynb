# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt

import networkx as nx

# %%
G=nx.Graph()

# %%
G

# %%
positions=nx.spring_layout(G)
G

# %%
nx.draw(G,pos=positions)
nx.draw_networkx_labels(G,pos=positions)
plt.draw()

# %%
coauthorshipG=nx.read_graphml("netScience.graphml")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-61-14fd2794da9e> in <module>
# ----> 1 coauthorshipG=nx.read_graphml("netScience.graphml")
#
# <decorator-gen-809> in read_graphml(path, node_type, edge_key_type, force_multigraph)
#
# ~\anaconda3\lib\site-packages\networkx\utils\decorators.py in _open_file(func_to_be_decorated, *args, **kwargs)
#     211         if isinstance(path, str):
#     212             ext = splitext(path)[1]
# --> 213             fobj = _dispatch_dict[ext](path, mode=mode)
#     214             close_fobj = True
#     215         elif hasattr(path, "read"):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'netScience.graphml'

# %%
import networkx as nx
G = nx.Graph()

# %%
G.add_node(1)

# %%
G.add_nodes_from([2, 3])

# %%
G.add_nodes_from([
    (4, {"color": "red"}),
    (5, {"color": "green"}),
])

# %%
G

# %%
H = nx.path_graph(10)
G.add_nodes_from(H)

# %%
G.add_node(H)

# %%
nx.Graph()

# %%
G = nx.path_graph(4)
print(nx.is_connected(G))
# Out:
# True

# %%
G = nx.path_graph(4)
print(nx.is_biconnected(G))
# Out:
# False

# %%
G.add_edge(0, 3)
print(nx.is_biconnected(G))
# Out:
# True

# %%
message = input('Enter a number') #encrypted message

for key in range(len(message)):
   translated = ''
   for symbol in message:
      if symbol in message:
         num = message.find(symbol)
         num = num - key
         if num < 0:
            num = num + len(message)
         translated = translated + message[num]
      else:
         translated = translated + symbol
print('Hacking key #%s: %s' % (key, translated))
# Out:
# Enter a number3214235252
# Hacking key #9: 2142122121

# %%
G = nx.complete_graph(message)
nx.draw(G)

# %%
G = nx.complete_graph(42)
nx.draw(G)

# %%
G1=nx.from_numpy_matrix(interactions_characters)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-6b6eb79407a3> in <module>
# ----> 1 G1=nx.from_numpy_matrix(interactions_characters)
#
# NameError: name 'interactions_characters' is not defined

# %%
nx.draw_networkx(G1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-97-4ebeae4d898f> in <module>
# ----> 1 nx.draw_networkx(G1)
#
# NameError: name 'G1' is not defined

# %%
H1    = nx.relabel_nodes(G1, character_map)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-98-25674b88de1f> in <module>
# ----> 1 H1    = nx.relabel_nodes(G1, character_map)
#
# NameError: name 'G1' is not defined

# %%
nx.draw_networkx(H1, node_color=range(numCharacters),font_color='black',width=0.3,alpha=0.7, 
                 font_size=10, cmap=matplotlib.cm.GnBu
                 ,node_size =[40*val for (node,val) in kdeg])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-efbffd62520d> in <module>
# ----> 1 nx.draw_networkx(H1, node_color=range(numCharacters),font_color='black',width=0.3,alpha=0.7,
#       2                  font_size=10, cmap=matplotlib.cm.GnBu
#       3                  ,node_size =[40*val for (node,val) in kdeg])
#
# NameError: name 'H1' is not defined
