# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/Users/kanso/OneDrive/Desktop/Kanso/University/Year 3/Principles of Data Science/Tutorial 2/passengerData.csv')

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %%
df2 = pd.read_csv('/Users/kanso/OneDrive/Desktop/Kanso/University/Year 3/Principles of Data Science/Tutorial 2/ticketPrices.csv')

df2
# Out:
#    TicketType  Fare
# 0           1    33
# 1           2    56
# 2           3    77
# 3           4    22
# 4           5    14
# 5           6    66
# 6           7    87
# 7           8    36

# %%
merged_data = df.merge(df2,on=["TicketType"])
merged_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              9         1       3
# 2             17         0       3
# 3             25         0       3
# 4             33         1       3
# ..           ...       ...     ...
# 886          856         1       3
# 887          864         0       3
# 888          872         1       1
# 889          880         1       1
# 890          888         1       1
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 2                                 Rice, Master. Eugene    male   2.0
# 3                        Palsson, Miss. Torborg Danira  female   8.0
# 4                             Glynn, Miss. Mary Agatha  female   NaN
# ..                                                 ...     ...   ...
# ...

# %%
Oldest =df['Age'].max()
Oldest
# Out:
# 80.0

# %%
Oldest = df[df["Age"] == 80]
Oldest
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  TicketType
# 630  male  80.0           7

# %%
merged_data.plot(x = 'Age', y = 'Fare', kind = 'scatter')  # plots all columns against index
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
merged_data.plot(x = ['Age'] , y = 'Fare', kind = 'scatter')  # plots all columns against index
# Out:
# <AxesSubplot:xlabel='[Age]', ylabel='Fare'>

# %%
Query = merged_data[merged_data ["Age"] > 40], [merged_data ["Age"] < 50], merged_data[merged_data ["Fare"] >= 40]
Query
# Out:
# (     PassengerId  Survived  Pclass  \
#  12            97         0       1
#  19           153         0       3
#  20           161         0       3
#  29           233         0       2
#  34           273         1       2
#  ..           ...       ...     ...
#  858          632         0       3
#  860          648         1       1
#  866          696         0       2
#  888          872         1       1
#  889          880         1       1
#
#                                                   Name     Sex   Age  \
#  12                          Goldschmidt, Mr. George B    male  71.0
#  19                                   Meo, Mr. Alfonzo    male  55.5
#  20                           Cribb, Mr. John Hatfield    male  44.0
#  29                          Sjostedt, Mr. Ernst Adolf    male  59.0
#  34          Mellinger, Mrs. (Elizabeth Anne Maidment)  female  41.0
#  ..                                                ...     ...   ...
# ...

# %%
Query.plot(x = ['Age'] , y = 'Fare', kind = 'scatter')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-127-f2447d873274> in <module>
# ----> 1 Query.plot(x = ['Age'] , y = 'Fare', kind = 'scatter')
#
# AttributeError: 'tuple' object has no attribute 'plot'

# %%
#_______________________Exercise TWO__________________________________

# %%
df3 = pd.read_csv('/Users/kanso/OneDrive/Desktop/Kanso/University/Year 3/Principles of Data Science/Tutorial 2/titanicSurvival_m.csv')

df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df3.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare            46
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df3.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  845.000000
# mean     0.381594   32.304319
# std      0.806057   49.792612
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.275000
# max      6.000000  512.329200

# %%
merged_data.fillna(df.mean(), inplace=True)
merged_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              9         1       3
# 2             17         0       3
# 3             25         0       3
# 4             33         1       3
# ..           ...       ...     ...
# 886          856         1       3
# 887          864         0       3
# 888          872         1       1
# 889          880         1       1
# 890          888         1       1
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.000000
# 2                                 Rice, Master. Eugene    male   2.000000
# 3                        Palsson, Miss. Torborg Danira  female   8.000000
# 4                             Glynn, Miss. Mary Agatha  female  29.699118
# ..                                                 ...     ...        ...
# ...

# %%
merged_data.plot(x = ['Age'] , y = 'Fare', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='[Age]', ylabel='Fare'>

# %%
print("When we replace the missing values in Age and Fare columns with the mean of each column our data becomes much more clear, we can see that all posibilities have now been plotted and that the data is more accurate. ")
# Out:
# When we replace the missing values in Age and Fare columns with the mean of each column our data becomes much more clear, we can see that all posibilities have now been plotted and that the data is more accurate.

# %%
merged_data['Age'] = merged_data['Age'].fillna(0)
merged_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              9         1       3
# 2             17         0       3
# 3             25         0       3
# 4             33         1       3
# ..           ...       ...     ...
# 886          856         1       3
# 887          864         0       3
# 888          872         1       1
# 889          880         1       1
# 890          888         1       1
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.000000
# 2                                 Rice, Master. Eugene    male   2.000000
# 3                        Palsson, Miss. Torborg Danira  female   8.000000
# 4                             Glynn, Miss. Mary Agatha  female  29.699118
# ..                                                 ...     ...        ...
# ...

# %%
merged_data['Fare'] = merged_data['Fare'].fillna(0)
merged_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              9         1       3
# 2             17         0       3
# 3             25         0       3
# 4             33         1       3
# ..           ...       ...     ...
# 886          856         1       3
# 887          864         0       3
# 888          872         1       1
# 889          880         1       1
# 890          888         1       1
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.000000
# 2                                 Rice, Master. Eugene    male   2.000000
# 3                        Palsson, Miss. Torborg Danira  female   8.000000
# 4                             Glynn, Miss. Mary Agatha  female  29.699118
# ..                                                 ...     ...        ...
# ...

# %%
#___________________________________EXCERSICE 3____________________________________________________

# %%
df4 = pd.read_csv('/Users/kanso/OneDrive/Desktop/Kanso/University/Year 3/Principles of Data Science/Tutorial 2/TB_burden_countries_2014-09-29.csv')

df4
# Out:
#           country iso2 iso3  iso_numeric g_whoregion  year  e_pop_num  \
# 0     Afghanistan   AF  AFG            4         EMR  1990   11731193
# 1     Afghanistan   AF  AFG            4         EMR  1991   12612043
# 2     Afghanistan   AF  AFG            4         EMR  1992   13811876
# 3     Afghanistan   AF  AFG            4         EMR  1993   15175325
# 4     Afghanistan   AF  AFG            4         EMR  1994   16485018
# ...           ...  ...  ...          ...         ...   ...        ...
# 4898     Zimbabwe   ZW  ZWE          716         AFR  2008   12784041
# 4899     Zimbabwe   ZW  ZWE          716         AFR  2009   12888918
# 4900     Zimbabwe   ZW  ZWE          716         AFR  2010   13076978
# 4901     Zimbabwe   ZW  ZWE          716         AFR  2011   13358738
# 4902     Zimbabwe   ZW  ZWE          716         AFR  2012   13724317
#
#       e_prev_100k  e_prev_100k_lo  e_prev_100k_hi  ...  e_inc_tbhiv_100k  \
# ...

# %%
df4.isna().sum()
# Out:
# country                        0
# iso2                          23
# iso3                           0
# iso_numeric                    0
# g_whoregion                    0
# year                           0
# e_pop_num                      0
# e_prev_100k                   11
# e_prev_100k_lo                11
# e_prev_100k_hi                11
# e_prev_num                    11
# e_prev_num_lo                 11
# e_prev_num_hi                 11
# e_mort_exc_tbhiv_100k          1
# e_mort_exc_tbhiv_100k_lo       1
# e_mort_exc_tbhiv_100k_hi       1
# e_mort_exc_tbhiv_num           1
# e_mort_exc_tbhiv_num_lo        1
# e_mort_exc_tbhiv_num_hi        1
# source_mort                    1
# e_inc_100k                     1
# e_inc_100k_lo                  1
# e_inc_100k_hi                  1
# e_inc_num                      1
# e_inc_num_lo                   1
# e_inc_num_hi                   1
# e_tbhiv_prct                1250
# e_tbhiv_prct_lo             1446
# ...

# %%
df4.fillna(df.mean(), inplace=True)
df4
# Out:
#           country iso2 iso3  iso_numeric g_whoregion  year  e_pop_num  \
# 0     Afghanistan   AF  AFG            4         EMR  1990   11731193
# 1     Afghanistan   AF  AFG            4         EMR  1991   12612043
# 2     Afghanistan   AF  AFG            4         EMR  1992   13811876
# 3     Afghanistan   AF  AFG            4         EMR  1993   15175325
# 4     Afghanistan   AF  AFG            4         EMR  1994   16485018
# ...           ...  ...  ...          ...         ...   ...        ...
# 4898     Zimbabwe   ZW  ZWE          716         AFR  2008   12784041
# 4899     Zimbabwe   ZW  ZWE          716         AFR  2009   12888918
# 4900     Zimbabwe   ZW  ZWE          716         AFR  2010   13076978
# 4901     Zimbabwe   ZW  ZWE          716         AFR  2011   13358738
# 4902     Zimbabwe   ZW  ZWE          716         AFR  2012   13724317
#
#       e_prev_100k  e_prev_100k_lo  e_prev_100k_hi  ...  e_inc_tbhiv_100k  \
# ...

# %%
df4.hist(figsize=(20,30), bins=20, layout=(15,4))
# Out:
# array([[<AxesSubplot:title={'center':'iso_numeric'}>,
#         <AxesSubplot:title={'center':'year'}>,
#         <AxesSubplot:title={'center':'e_pop_num'}>,
#         <AxesSubplot:title={'center':'e_prev_100k'}>],
#        [<AxesSubplot:title={'center':'e_prev_100k_lo'}>,
#         <AxesSubplot:title={'center':'e_prev_100k_hi'}>,
#         <AxesSubplot:title={'center':'e_prev_num'}>,
#         <AxesSubplot:title={'center':'e_prev_num_lo'}>],
#        [<AxesSubplot:title={'center':'e_prev_num_hi'}>,
#         <AxesSubplot:title={'center':'e_mort_exc_tbhiv_100k'}>,
#         <AxesSubplot:title={'center':'e_mort_exc_tbhiv_100k_lo'}>,
#         <AxesSubplot:title={'center':'e_mort_exc_tbhiv_100k_hi'}>],
#        [<AxesSubplot:title={'center':'e_mort_exc_tbhiv_num'}>,
#         <AxesSubplot:title={'center':'e_mort_exc_tbhiv_num_lo'}>,
#         <AxesSubplot:title={'center':'e_mort_exc_tbhiv_num_hi'}>,
#         <AxesSubplot:title={'center':'e_inc_100k'}>],
# ...
